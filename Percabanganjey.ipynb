# %% [markdown]
# <a href="https://colab.research.google.com/github/azharrabbaniti25-cmd/Percabangan.ipynb/blob/main/Percabanganjey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Buatlah program yang meminta pengguna memasukkan usia seseorang, lalu tentukan apakah dia <br>
# anak-anak (0-12 tahun), remaja (13-17 tahun), dewasa (18-59 tahun), atau lansia (60 tahun ke atas).

# %%
try:
    usia = int(input("Masukkan usia Anda: "))

    if usia < 0:
        print("Usia tidak valid. Masukan angka positif.")
    elif usia <= 12:
        kategori = "Anak-anak"
    elif usia <= 17:
        kategori = "Remaja"
    elif usia <= 59:
        kategori = "Dewasa"
    else:
        kategori = "Lansia"

    if usia >= 0:
        print(f"Seseorang dengan usia {usia} tahun termasuk kategori: {kategori}")

except ValueError:
    print("Input tidak valid! Harap masukkan angka bulat.")
# Out:
# Masukkan usia Anda: 30
# Seseorang dengan usia 30 tahun termasuk kategori: Dewasa

# %% [markdown]
# Sebuah taman hiburan memiliki aturan harga tiket berdasarkan usia:
# <ol>
# <li>Anak-anak (0-12 tahun): Rp 10.000</li>
# <li>Remaja (13-17 tahun): Rp 15.000</li>
# <li>Dewasa (18-59 tahun): Rp 25.000</li>
# <li>Lansia (60 tahun ke atas): Gratis</li>
# </ol>
# Buat program untuk menentukan harga tiket berdasarkan usia yang dimasukkan pengguna dan total harga yang harus dibayar, jika terdapat 3 input seperti berikut ini

# %%
tiket1 = int(input("Isikan Umur Tiket 1: "))
tiket2 = int(input("Isikan Umur Tiket 2: "))
tiket3 = int(input("Isikan Umur Tiket 3: "))

# add code here ...

if tiket1 <= 12:
    harga1 = 10000
elif tiket1 <= 17:
    harga1 = 15000
elif tiket1 <= 59:
    harga1 = 25000
else:
    harga1 = 0

if tiket2 <= 12:
    harga2 = 10000
elif tiket2 <= 17:
    harga2 = 15000
elif tiket2 <= 59:
    harga2 = 25000
else:
    harga2 = 0

if tiket3 <= 12:
    harga3 = 10000
elif tiket3 <= 17:
    harga3 = 15000
elif tiket3 <= 59:
    harga3 = 25000
else:
    harga3 = 0

total_bayar = harga1 + harga2 + harga3

print("\n--- Rincian Harga ---")
print("Harga Tiket 1: Rp", harga1)
print("Harga Tiket 2: Rp", harga2)
print("Harga Tiket 3: Rp", harga3)
print("----------------------")
print("Total Bayar  : Rp", total_bayar)
# Out:
# Isikan Umur Tiket 1: 12
# Isikan Umur Tiket 2: 17
# Isikan Umur Tiket 3: 30
#
# --- Rincian Harga ---
# Harga Tiket 1: Rp 10000
# Harga Tiket 2: Rp 15000
# Harga Tiket 3: Rp 25000
# ----------------------
# Total Bayar  : Rp 50000

# %% [markdown]
# Sebuah restoran memiliki diskon khusus:
# Anak-anak (0-12 tahun) diskon 50%
# Lansia (60 tahun ke atas) diskon 30%
# Selain itu, tidak ada diskon
# Buat program untuk menghitung harga yang harus dibayar setelah diskon diberikan.

# %%
# add code here ...

harga_dasar = float(input("Masukan harga total makanan (Rp): "))
usia = int(input("Masukan usia pelanggan: "))

if usia >= 0 and usia <= 12:
    persen_diskon = 50
    kategori = "Anak--anak"
if usia >= 60:
    persen_diskon = 30
    kategori = "Lansia"
potongan = harga_dasar * (persen_diskon / 100)
harga_akhir = harga_dasar - potongan

print("\n--- Rincian Pembayaran ---")
print(f"Kategori      : {kategori}")
print(f"Diskon        : {persen_diskon}%")
potongan = 50000.0
print(f"Potongan Harga: Rp {potongan:,.0f}")
print("----------------------")
print(f"Total Bayar   : Rp {harga_akhir:,.0f}")
# Out:
# Masukan harga total makanan (Rp): 90000
# Masukan usia pelanggan: 80
#
# --- Rincian Pembayaran ---
# Kategori      : Lansia
# Diskon        : 30%
# Potongan Harga: Rp 50,000
# ----------------------
# Total Bayar   : Rp 63,000

# %% [markdown]
# Program beasiswa:
# <ol>
# <li>Jika nilai rapor ≥ 90 dan penghasilan orang tua < Rp 5.000.000 → Beasiswa Penuh</li>
# <li>Jika nilai rapor ≥ 85 dan penghasilan orang tua < Rp 8.000.000 → Beasiswa 50%</li>
# <li>Jika tidak memenuhi syarat di atas → Tidak mendapatkan beasiswa</li>
# </ol>

# %%
# add code here ...

nilai  = float(input("Masukan nilai rapor: "))
penghasilan = int(input("Masukan penghasilan orang tua: "))

if nilai >= 90 and penghasilan < 5000000:
   print("Hasil: Selamat! Anda Mendapatkan Beasiswa Penuh.")
elif nilai >= 85 and penghasilan > 8000000:
    print("Hasil: Anda Mendapatkan Beasiswa 50%.")
else :
    print("Hasil: Anda Belum Memenuhi Syarat Beasiswa.")
# Out:
# Masukan nilai rapor: 86
# Masukan penghasilan orang tua: 9000000
# Hasil: Anda Mendapatkan Beasiswa 50%.

# %% [markdown]
# Suatu aplikasi streaming memiliki batasan usia:
# <ol>
# <li>Film Semua Umur: Bisa ditonton oleh siapa saja</li>
# <li>Film Remaja: Hanya untuk usia ≥ 13 tahun</li>
# <li>Film Dewasa: Hanya untuk usia ≥ 18 tahun</li>
# </ol>
# Buat program yang meminta input usia dan kategori film, lalu tentukan apakah seseorang boleh menonton film tersebut atau tidak.

# %%
# add code here ...

usia = int(input("Masukan Usia Anda:"))
kategori = input("Pilih kategori film (Semua Umur/ Remaja / Dewasa): ").strip().lower()

boleh_nonton = False

if kategori == "semua umur":
   boleh_nonton = True
elif kategori == "remaja":
   if usia >= 13:
    boleh_nonton = True
elif kategori == "dewasa":
   if usia >= 18:
    boleh_nonton = True

else:
  print("kategori tidak valid!")
  exit()

if boleh_nonton:
  print(f"Izin diberikan. Selamat menonton kategori film {kategori.upper()}!")
else:
  print(f"Untuk sekarang maaf, Anda belum cukup umur untuk menonton film kategori{kategori.upper()} ")
# Out:
# Masukan Usia Anda:15
# Pilih kategori film (Semua Umur/ Remaja / Dewasa): dewasa
# Untuk sekarang maaf, Anda belum cukup umur untuk menonton film kategoriDEWASA

# %% [markdown]
# Sebuah toko memberikan diskon berdasarkan jumlah pembelian:
# <ol>
# <li>Jika total belanja ≥ Rp 500.000 → Diskon 20%</li>
# <li>Jika total belanja ≥ Rp 250.000 → Diskon 10%</li>
# <li>Jika total belanja < Rp 250.000 → Tidak ada diskon</li>
# </ol>
# Hitung harga akhir setelah diskon.

# %%
# add code here

total_belanja = float(input("Masukan total belanja anda (Rp): "))

if total_belanja >=500000:
   persen_diskon = 20
elif total_belanja >=250000:
   persen_diskon = 10
else:
   persen_diskon = 0

nominal_diskon = (persen_diskon /100) * total_belanja
harga_akhir = total_belanja - nominal_diskon

print("-" * 30)
print(f"Total_belanja: Rp {total_belanja:,.0f}")
print(f"Diskon ({persen_diskon}%)  : Rp {nominal_diskon:,.0f}")
print(f"Harga akhir  : Rp {harga_akhir:,.0f}")
print("-" * 30)
# Out:
# Masukan total belanja anda (Rp): 600000
# ------------------------------
# Total_belanja: Rp 600,000
# Diskon (20%)  : Rp 120,000
# Harga akhir  : Rp 480,000
# ------------------------------

# %% [markdown]
# Program parkir:
# <ol>
# <li>Mobil: Rp 5.000 per jam</li>
# <li>Motor: Rp 2.000 per jam</li>
# <li>Jika parkir lebih dari 5 jam, ada biaya tambahan Rp 10.000</li>
# </ol>
# Hitung total biaya parkir berdasarkan jenis kendaraan dan durasi parkir.

# %%
# add code here

jenis_kendaraan = input("Masukan jenis kendaraan (Mobil/Motor): ").strip(). lower()
durasi = float(input("Masukan durasi parkir (Jam): "))

if jenis_kendaraan == "mobil":
  biaya_per_jam = 5000
elif jenis_kendaraan == "motor":
  biaya_per_jam = 2000
else:
    print("Jenis kendaraan tidak valid!")
exit()

total_biaya = biaya_per_jam * durasi

if durasi > 5:
  total_tambahan = 10000
  print("Catatan. Biaya tambahan 10000 karna parkir > 5 jam.")

print("-" * 35)
print(f"Jenis Kendaraan: {jenis_kendaraan.capitalize()}")
print(f"Durasi parkir  : {durasi} jam")
print(f"Total Tagihan  : {total_biaya:,.0f}")
print("-" * 35)
# Out:
# Masukan jenis kendaraan (Mobil/Motor): Mobil
# Masukan durasi parkir (Jam): 10
# Catatan. Biaya tambahan 10000 karna parkir > 5 jam.
# -----------------------------------
# Jenis Kendaraan: Mobil
# Durasi parkir  : 10.0 jam
# Total Tagihan  : 50,000
# -----------------------------------

# %% [markdown]
# Aplikasi transportasi online memiliki tarif sebagai berikut:
# <ol>
# <li>Jika jarak ≤ 5 km → Rp 5.000/km</li>
# <li>Jika jarak 6-10 km → Rp 4.000/km</li>
# <li>Jika jarak > 10 km → Rp 3.000/km</li>
# </ol>
# Hitung tarif perjalanan berdasarkan jarak yang dimasukkan pengguna.

# %%
# add code here

jarak = float(input("Masukan jarak perjalanan (km):"))

if jarak <= 0:
  print("Jarak harus lebih dari 0km.")
elif jarak <= 5:
  tarif_per_km = 5000
elif jarak <= 10:
  tarif_per_km = 4000
else:
  tarif_per_km = 3000

if jarak > 0:
  total_tarif = jarak * tarif_per_km
  print("------ Rincian Tarif -------")
  print(f"Jarak tempuh  : {jarak} km")
  print(f"Tarif per km  : Rp {tarif_per_km:,.0f}")
  print(f"Total tarif   : Rp {total_tarif}:,.0f")
# Out:
# Masukan jarak perjalanan (km):20
# ------ Rincian Tarif -------
# Jarak tempuh  : 20.0 km
# Tarif per km  : Rp 3,000
# Total tarif   : Rp 60000.0:,.0f

# %% [markdown]
# Buatlah sebuah sistem penerimaan calon programmer yang akan menerima dua nilai ( nilai coding dan nilai interview). Untuk penilaian test coding skala penilaian yang diberikan dimulai dari 0 hingga 100 dengan sistem penilaian:
# <ol>
# <li>ketika seseorang mendapatkan nilai lebih dari 80 maka peserta tersebut akan mendapatkan hasil tes LOLOS</li>
# <li>ketika sesorang mendapatkan nilai diantara 60 hingga 80 maka peserta tersebut mendapatkan hasil tes DIPERTIMBANGKAN</li>
# <li>ketika seseorang mendapatkan nilai dibawah 60 maka peserta tersebut mendapatkan hasil tes GAGAL.</li>
# </ol>
#
# Sedangkan untuk penilaian interview adalah
# <ol>
# <li>ketika nilai yang diberikan kepada seseorang tersebut adalah "A" atau "B" maka peserta tersebut dianggap LOLOS interview</li>
#
# <li>selain kedua nilai tersebut maka peserta dianggap GAGAL tes interview.</li>
# </ol>
#
# Ketika calon programmer mendapatkan nilai coding LOLOS atau DIPERTIMBANGKAN dan juga LOLOS test interview maka tampilkanlah pesan "Selamat Kamu Berhasil Menjadi Calon Programmer". Jika tidak maka tampilkanlah pesan "Maaf Kamu Belum Berhasil Menjadi Calon Programmer"

# %%
# add code here

nilai_coding = int(input("Masukan nilai coding (0-100): "))
nilai_interview = input("Masukan nilai interview (A/B): ").upper()

if nilai_coding > 80:
  status_coding = "LOLOS"
elif 60 <= nilai_coding <= 80:
  status_coding = "DIPERTIMBANGKAN"
else:
  status_coding = "GAGAL"

if nilai_interview == "A" or nilai_interview == "B":
  status_interview = "LOLOS"
else:
  status_interview = "GAGAL"

if (status_coding == "LOLOS" or status_coding == "DIPERTIMBANGKAN") and status_interview == "LOLOS":
  print("Selamat Kamu Berhasil Menjadi Calon Programer")
else:
  print("Maaf Kamu Belum Berhasil Menjadi Calon Programer")
# Out:
# Masukan nilai coding (0-100): 90
# Masukan nilai interview (A/B): D
# Maaf Kamu Belum Berhasil Menjadi Calon Programer

# %% [markdown]
# Sebuah klub sepak bola “PERSEGI FC” mempunyai aturan dalam memberikan nomor punggung bagi para pemainnya. Para pemain diperbolehkan mempunyai posisi lebih dari 1. Berikut adalah beberapa
# aturannya:
# <ol>
# <li>Untuk nomor punggung genap, digunakan untuk posisi “target attacker”</li>
# <li>Untuk nomor punggung genap antara 50 – 100, digunakan untuk pemain yang “berhak dipilih menjadi capten team”</li>
# <li>Untuk nomor punggung ganjil, digunakan untuk posisi “defender”</li>
# <li>Untuk nomor punggung ganjil lebih dari 90, digunakan untuk posisi “Playmaker”</li>
# <li>Untuk nomor punggung ganjil kelipatan dari 3 dan 5, digunakan untuk posisi “keeper”</li>
# </ol>
# Buatlah program untuk melakukan pengecekan sebuah nomor punggung dapat berfungsi sebagai posisi apa saja.

# %%
def cek_posisi_pemain(nomor):
  posisi = []

  if nomor % 2 == 0:
    posisi.append("Target Attacker")
    if 50 <= nomor <= 100:
      posisi.append("Berhak dipilih menjadi Captain Team")
  else:
    posisi.append("Defender")
    if nomor > 90:
      posisi.append("Playmaker")
    if nomor % 3 == 0 and nomor % 5 == 0:
      posisi.append("Keeper")

  print("--- Analisis Nomor Punggung {} ---".format(nomor))
  if posisi:
    for p in posisi:
      print(f"- {p}")
  else:
    print("- Tidak ditemukan posisi yang sesuai.")
  print("-" * 30)

nomor_input = int(input("Masukan nomor punggung:"))
cek_posisi_pemain(nomor_input)
# Out:
# Masukan nomor punggung:35
# --- Analisis Nomor Punggung 35 ---
# - Defender
# ------------------------------
